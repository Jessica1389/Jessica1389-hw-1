# %% [markdown]
# # Homework 1
# This is the introductionary homework to learn about how code sharing works.
#
# ## About me
# My name is Jessica Svensson and I have been studying mathematics. I am writing my bachelors thesis next year.
#
# ## Prior experience with data science
# My first experience with data science was in upper secondary high school, where I was introduced to Python and Csharp. Since then I have done courses in programming at SU to further learn programming. I have sharpened my knowledge in Python and learnt R code.

# %% [markdown]
# ## Simple figure and table
# I have used the code from the example in homework 1 instructions. The code below saves the csv file into the data folder.

# %%
import os
import seaborn as sns

# Load data
tips = sns.load_dataset("tips")

# Save the data
tips.to_csv("data/tips.csv", index=False)

# %% [markdown]
# I will now use the data to plot using seaborn, sns module.

# %%
import seaborn as sns

tips = sns.load_dataset("tips")
sns.scatterplot(data=tips, x = "total_bill", y="tip", hue="sex")

tips.groupby('sex', observed=False)[['total_bill','tip']].mean()
# Out:
#         total_bill       tip
# sex
# Male     20.744076  3.089618
# Female   18.056897  2.833448

# %% [markdown]
# ## Reproducibility
# This notebook was done in a Conda environment, with Python 3.10.
# You will need packages: See requirements txt
#
# To reproduce:
# 1. Create environment:
#        conda create --name hw1_env python=3.10 pandas matplotlib seaborn -y
#        conda activate hw1_env
# 2. Install required packages:
#    pip install -r Requirements.txt
# 3. Open the notebook in Jupyterlab, Jupyter Notebook or VS Code
# 4. Run all cells subsequentially
#
# Notes:
# - OBS! Data is included in the file called data. Running cell one for data creation is optional.
# - Data comes from Seaborn built-in dataset "tips". No extra downloads are needed.
